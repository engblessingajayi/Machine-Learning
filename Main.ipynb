# %%
from fileHandler.excelHandler import Filehandler

# %%
myFileHandler = Filehandler("./dataFiles/final_project.xlsx")

myFileHandler.xlsxHandler()
# Out:
#     Relative_Humidity_Percentage  Temperature_Degree_Celsius
# 0                             45                        27.0  \
# 1                             47                        26.0
# 2                             47                        26.7
# 3                             47                        26.0
# 4                             46                        24.3
# ..                           ...                         ...
# 95                            54                        27.3
# 96                            60                        26.6
# 97                            66                        26.4
# 98                            64                        25.9
# 99                            58                        25.6
#
#     Indoor_Mould_CFU_m3
# 0                2968.2
# 1                4735.0
# 2                 282.7
# 3                  70.7
# 4                  84.8
# ..                  ...
# 95                 49.5
# 96                 63.6
# ...

# %%
myFileHandler.project50Handler()

# %%
firstSection = Filehandler("./dataFiles/halfData.xlsx")

# %%
firstSection.xlsxHandler()
# Out:
#     Relative_Humidity_Percentage  Temperature_Degree_Celsius
# 0                             45                        27.0  \
# 1                             47                        26.0
# 2                             47                        26.7
# 3                             47                        26.0
# 4                             46                        24.3
# 5                             46                        25.1
# 6                             45                        24.8
# 7                             51                        24.0
# 8                             51                        24.0
# 9                             48                        24.0
# 10                            46                        23.8
# 11                            50                        23.7
# 12                            47                        23.9
# 13                            46                        24.0
# ...
